# %%
import numpy as np
import nengo

import matplotlib.pyplot as plt
# %matplotlib inline

from preprocess import *

# %%
circle_points = nengo.dists.UniformHypersphere(surface=True).sample(200, 2)
print(circle_points.shape)
# Out:
# (200, 2)

# %%
plt.scatter(circle_points[:, 0], circle_points[:, 1])

# %%
# can I sample from a sinusoid and cosine thing, I mean, duh...
# just pass in the t_range you absolute walnut
dt = 0.001
trange = (0, np.round(2*np.pi, decimals=3))
t_val = np.arange(trange[0], trange[1], dt)
plt.scatter(np.cos(t_val), np.sin(t_val))

# %%
# how the fuck do you connect these things?
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-76255a9b82a2> in <module>()
#       1 np.cos(trange).shape
# ----> 2 trange.shape
#
# AttributeError: 'tuple' object has no attribute 'shape'
